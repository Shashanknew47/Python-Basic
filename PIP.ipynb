# %%
#To check existing modules
# !pip help
# Out:
# Usage:
#   pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ----------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.6
# anaconda-project                   0.8.2
# appdirs                            1.4.3
# asn1crypto                         0.24.0
# astroid                            2.1.0
# astropy                            3.1
# atomicwrites                       1.2.1
# attrs                              18.2.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.6.3
# bitarray                           0.8.3
# bkcharts                           0.2
# blaze                              0.11.3
# bleach                             3.0.2
# bokeh                              1.0.2
# boto                               2.49.0
# ...

# %%
#To check outdated packages below command or shortcut is pip list -o
# !pip list --outdated
# Out:
# Package                  Version    Latest      Type
# ------------------------ ---------- ----------- -----
# appdirs                  1.4.3      1.4.4       wheel
# asn1crypto               0.24.0     1.3.0       wheel
# astroid                  2.1.0      2.4.2       wheel
# astropy                  3.1        4.0.1.post1 wheel
# atomicwrites             1.2.1      1.4.0       wheel
# attrs                    18.2.0     19.3.0      wheel
# Babel                    2.6.0      2.8.0       wheel
# backcall                 0.1.0      0.2.0       wheel
# beautifulsoup4           4.6.3      4.9.1       wheel
# bitarray                 0.8.3      1.4.2       sdist
# bleach                   3.0.2      3.1.5       wheel
# bokeh                    1.0.2      2.1.1       sdist
# Bottleneck               1.2.1      1.3.2       sdist
# certifi                  2019.11.28 2020.6.20   wheel
# cffi                     1.11.5     1.14.0      wheel
# ...

# %%
# To update a package 
# !pip install -U numpy
# Out:
# ...
#   Found existing installation: numpy 1.15.4
#     Uninstalling numpy-1.15.4:
#       Successfully uninstalled numpy-1.15.4
# ...

# %%
#Unstalling a package from jypyter notebook
# !python -m pip uninstall beautifulsoup4 --yes
# Out:
# Found existing installation: beautifulsoup4 4.6.3
# Uninstalling beautifulsoup4-4.6.3:
#   Successfully uninstalled beautifulsoup4-4.6.3

# %%
# If you want to provide a list of packages which you are using then 
# !pip freeze
# Out:
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.6
# anaconda-project==0.8.2
# appdirs==1.4.3
# asn1crypto==0.24.0
# astroid==2.1.0
# astropy==3.1
# atomicwrites==1.2.1
# attrs==18.2.0
# Babel==2.6.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.6.3
# bitarray==0.8.3
# bkcharts==0.2
# blaze==0.11.3
# bleach==3.0.2
# bokeh==1.0.2
# boto==2.49.0
# Bottleneck==1.2.1
# bs4==0.0.1
# certifi==2019.11.28
# cffi==1.11.5
# chardet==3.0.4
# Click==7.0
# cloudpickle==0.6.1
# clyent==1.2.2
# colorama==0.4.1
# comtypes==1.1.7
# conda==4.8.2
# conda-build==3.17.6
# conda-package-handling==1.3.11
# conda-verify==3.1.1
# contextlib2==0.5.5
# cryptography==2.4.2
# cssselect==1.1.0
# cycler==0.10.0
# Cython==0.29.2
# cytoolz==0.9.0.1
# dask==1.0.0
# datashape==0.5.4
# decorator==4.3.0
# defusedxml==0.5.0
# distributed==1.25.1
# docutils==0.14
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fake-useragent==0.1.11
# ...

# %%
# !pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\users\shashank\anaconda3\lib\site-packages (20.1.1)

# %%
# If you want to give all these packages in a file then use below command which will create a file of all packages.
# !pip freeze > Python_packages.txt

# %%
# !pip install pytz
# Out:
# ...
# ERROR: conda-build 3.17.6 requires beautifulsoup4, which is not installed.

# %%
# To install all packages from a file.use
# !pip install -r  Python_packages.txt
# Out:
# ...
#   Using cached beautifulsoup4-4.6.3-py3-none-any.whl (90 kB)
# ...

# %%
#To check a package status in package manager(pip)
# !pip search beautifulsoup4
# Out:
# beautifulsoup4-slurp (0.0.2)  - Slurp packages Beautifulsoup4 into command line.
# beautifulsoup4 (4.9.1)        - Screen-scraping library
#   INSTALLED: 4.6.3
#   LATEST:    4.9.1
# zapimoveis_scraper (0.2.1)    - ZAP Im&#243;veis crawler and scraper using beautifulsoup4
# soup_helpers (0.0.8)          - A simple set of BeautifulSoup4 unit test helpers
# parse-helper (0.1.21)         - Helpers to fetch & parse text on pages with requests, lxml, & beautifulsoup4

# %%
# !pip freeze --local | cut -d = -f 1
# Out:
# 'cut' is not recognized as an internal or external command,
# operable program or batch file.
